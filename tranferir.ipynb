# %%
import geopandas as gpd
import os

# %%
path = r"C:\Users\Rodrigo\Desktop\dados.gdb"

# %%
gdf_gdb_0 = gpd.read_file(path, layer=0)
gdf_gdb_1 = gpd.read_file(path, layer=1)

# %%
gdf_gdb_1
# Out:
#         CD_USO_SOLO  CD_UNIDADE  ID_REGIAO ID_PROJETO       PROJETO CD_TALHAO  \
# 0           44795.0         1.0       11.0        588     MOTRISA I    V03416
# 1           44814.0         1.0       11.0        588     MOTRISA I    V03417
# 2           25554.0         1.0       11.0        588     MOTRISA I    V03408
# 3           25552.0         1.0       11.0        588     MOTRISA I    V03409
# 4           25547.0         1.0       11.0        588     MOTRISA I    V03414
# ...             ...         ...        ...        ...           ...       ...
# 101089     310506.0         1.0       11.0        702  GOIABEIRA II    V00102
# 101090      54494.0         1.0       11.0        306       TUPANCY    V00203
# 101091     279801.0         1.0       11.0        002   BARBA NEGRA      252E
# 101092     300638.0         1.0       11.0        019  DOURADILHO I      008A
# 101093     298549.0         1.0       11.0        077     ALDO SANI      016K
#
# ...

# %%
path = r"C:\optimusGIS\cmpc_mato\cmpc-0121\dados\ARQUIVOS_BASE\ENTRADA\dados_area_cadastro.gpkg"

# %%
gdf_gdb_1.to_file(path, layer="dados_area_cadastro", driver="GPKG")
